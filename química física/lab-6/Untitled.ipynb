# %%
# Код для генерации схемы сравнения архитектур (Matplotlib)
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,6))

# Данные для графика (примерные значения)
technologies = ['Traditional\nNetworking', 'SDN\n(Basic)', 'SDN\n(with AI)']
latency = [45, 32, 24]
throughput = [60, 75, 90]

x = np.arange(len(technologies))
width = 0.35

plt.bar(x - width/2, latency, width, label='Задержка (мс)', color='lightcoral')
plt.bar(x + width/2, throughput, width, label='Пропускная способность (%)', color='lightgreen')

plt.xlabel('Архитектура')
plt.ylabel('Показатели')
plt.title('Сравнение сетевых архитектур')
plt.xticks(x, technologies)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig('sdn_vs_traditional.png', dpi=300)
plt.show()
